# %%
import os

# Change the current working directory to a different directory
os.chdir("/home/adham.ibrahim/speech_datasets/train")

# %%
import os
import pandas as pd

# Specify the directory path
directory_path = '/home/adham.ibrahim/speech_datasets/train'

# Initialize an empty dictionary to store the DataFrames
data_dict = {}

# Iterate through subdirectories
for folder_name in os.listdir(directory_path):
    folder_path = os.path.join(directory_path, folder_name)
    
    # Check if the item in the directory is a subdirectory
    if os.path.isdir(folder_path):
        
        # Construct the expected CSV file path (assuming the CSV file has the same name as the folder)
        csv_file_path = os.path.join(folder_path, f'{folder_name}.csv')
      
        # Check if the CSV file with the same name as the folder exists
        if os.path.exists(csv_file_path):
            
            # Read the CSV file into a DataFrame
            df = pd.read_csv(csv_file_path)
            
            # Store the DataFrame in the dictionary with the folder name as the key
            data_dict[folder_name] = df

# Now, data_dict contains DataFrames for each subdirectory where the keys are the subdirectory names

# %%
data_dict.keys()
# Out:
# dict_keys(['Emotion_Speech_Dataset', 'emov_db', 'MELD.Raw', 'savee', 'CREMA-D', 'ravdess', 'IEMOCAP_full_release', 'JL_corpus'])

# %%
# Iterate through the data_dict and make the "Emotion" column values lowercase
for folder_name, df in data_dict.items():
    if "Emotion" in df.columns:
        df["Emotion"] = df["Emotion"].str.lower()

# Iterate through the data_dict and make the "Emotion" column values lowercase
for folder_name, df in data_dict.items():
    if "Gender" in df.columns:
        df["Gender"] = df["Gender"].str.lower()

# %%
# Define a mapping of values to be replaced
emotion_mapping = {
    'neutral': 'neu',
    'angry': 'ang',
    'happy': 'hap',
    'surprised': 'sur',
    'surprise': 'sur',
    'disgust': 'dis',
    'disgusted': 'dis',
    'fear': 'fea',
    'fearful': 'fea',
    'excited' : 'exc'
}

# Iterate through the data_dict and apply the mapping to the "Emotion" column
for folder_name, df in data_dict.items():
    if "Emotion" in df.columns:
        df["Emotion"] = df["Emotion"].replace(emotion_mapping)

# %%
# import librosa
# import soundfile

# dataset = ['Emotion_Speech_Dataset', 'emov_db', 'MELD.Raw', 'savee', 'CREMA-D', 'ravdess', 'IEMOCAP_full_release', 'JL_corpus']
# def change_sample_rate(file_path, target_sample_rate=16000):
#     try:
#         # Load audio file
#         audio, sr = librosa.load(file_path, sr=None)

#         # Check if the sample rate needs to be changed
#         if sr != target_sample_rate:
#             # Resample the audio
#             audio_resampled = librosa.resample(y = audio, orig_sr = sr, target_sr= target_sample_rate)

#             # Save the resampled audio
#             soundfile.write(file_path, audio_resampled, target_sample_rate)

#             print(f"Sample rate changed to {target_sample_rate} Hz for file: {file_path}")
#         else:
#             print(f"Sample rate is already {target_sample_rate} Hz for file: {file_path}")

#     except Exception as e:
#         print(f"Error processing {file_path}: {e}")

# # Assuming data_dict is your dictionary and dataset is a list of indices
# # For example: dataset = [1, 2, 3, ...]
# for i in range(len(dataset)):
#     file_paths = data_dict[dataset[i]]['File_Path']

#     for file_path in file_paths:
#         change_sample_rate(file_path)
# Out:
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000928.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000914.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000900.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000733.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000727.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000848.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000860.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000874.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_001029.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_001001.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_001015.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_001014.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_001000.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_001028.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000875.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000861.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000849.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000726.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000732.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000901.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000915.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000929.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000903.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000917.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000724.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000730.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000718.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000877.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000863.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000888.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_001016.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_001002.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_001003.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_001017.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000889.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000862.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000876.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000719.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000731.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000725.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000916.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000902.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000906.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000912.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000709.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000721.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000735.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000872.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000866.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000899.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_001013.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_001007.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_001006.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_001012.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000898.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000867.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000873.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000734.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000720.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000708.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000913.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000907.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000911.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000905.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000939.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000736.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000722.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000865.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000871.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000859.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_001004.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_001010.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_001038.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_001039.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_001011.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_001005.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000858.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000870.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000864.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000723.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000737.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000938.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000904.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000910.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000793.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000787.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000977.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000963.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000988.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000750.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000744.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000778.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000803.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000817.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000816.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000802.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000779.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000745.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000751.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000989.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000962.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000976.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000786.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000792.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000784.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000790.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000948.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000960.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000974.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000747.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000753.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000828.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000814.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000800.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_001049.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_001048.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000801.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000815.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000829.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000752.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000746.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000975.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000961.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000949.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000791.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000785.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000965.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000971.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000781.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000959.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000795.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000742.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000756.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000811.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000805.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000839.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000838.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000804.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000810.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000757.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000743.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000794.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000958.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000780.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000970.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000964.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000972.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000966.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000796.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000782.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000769.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000755.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000999.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000741.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000806.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000812.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000813.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000807.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000740.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000998.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000754.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000768.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000783.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000797.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000967.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000973.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000956.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000942.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000771.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000765.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000995.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000981.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000759.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000822.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000836.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_001043.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_001042.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000837.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000823.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000758.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000980.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000994.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000764.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000770.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000943.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000957.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000969.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000799.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000941.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000955.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000766.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000772.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000982.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000996.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000809.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000835.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000821.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_001040.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_001041.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000820.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000834.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000808.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000997.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000983.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000773.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000767.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000954.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000940.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000798.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000968.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000944.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000788.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000950.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000978.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000987.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000993.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000763.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000777.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000830.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000824.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000818.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_001045.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_001044.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_001050.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000819.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000825.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000831.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000776.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000762.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000992.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000986.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000979.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000951.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000789.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000945.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000953.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000947.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000990.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000748.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000984.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000774.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000760.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000827.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000833.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_001046.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_001047.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000832.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000826.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000761.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000775.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000985.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000749.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000991.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000946.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000952.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000909.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000935.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000921.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000712.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000706.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000869.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000841.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000855.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000882.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000896.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_001008.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_001020.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_001034.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_001035.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_001021.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_001009.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000897.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000883.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000854.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000840.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000868.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000707.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000713.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000920.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000934.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000908.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000922.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000936.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000705.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000711.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000739.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000856.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000842.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000895.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000881.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_001037.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_001023.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_001022.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_001036.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000880.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000894.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000843.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000857.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000738.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000710.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000704.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000937.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000923.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000927.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000933.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000728.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000714.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000853.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000847.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000890.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000884.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_001032.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_001026.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_001027.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_001033.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000885.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000891.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000846.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000852.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000715.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000701.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000729.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000932.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000926.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000930.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000924.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000918.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000717.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000703.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000844.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000850.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000878.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000887.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000893.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_001025.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_001031.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_001019.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_001018.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_001030.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_001024.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000892.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000886.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000879.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000851.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000845.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000702.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000716.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000919.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000925.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Happy/0020_000931.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Sad/0020_001149.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Sad/0020_001175.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Sad/0020_001161.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Sad/0020_001388.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Sad/0020_001377.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Sad/0020_001363.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Sad/0020_001203.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Sad/0020_001217.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Sad/0020_001216.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Sad/0020_001202.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Sad/0020_001362.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Sad/0020_001376.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Sad/0020_001389.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Sad/0020_001160.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Sad/0020_001174.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Sad/0020_001148.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Sad/0020_001189.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Sad/0020_001162.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Sad/0020_001176.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Sad/0020_001348.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Sad/0020_001360.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Sad/0020_001374.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Sad/0020_001228.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Sad/0020_001214.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Sad/0020_001200.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Sad/0020_001201.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Sad/0020_001215.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Sad/0020_001229.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Sad/0020_001375.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Sad/0020_001361.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Sad/0020_001349.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Sad/0020_001177.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Sad/0020_001163.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Sad/0020_001188.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Sad/0020_001198.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Sad/0020_001167.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Sad/0020_001173.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Sad/0020_001365.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Sad/0020_001371.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Sad/0020_001359.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Sad/0020_001211.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Sad/0020_001205.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Sad/0020_001239.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Sad/0020_001238.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Sad/0020_001204.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Sad/0020_001210.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Sad/0020_001358.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Sad/0020_001370.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Sad/0020_001364.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Sad/0020_001172.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Sad/0020_001166.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Sad/0020_001199.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Sad/0020_001170.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Sad/0020_001164.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Sad/0020_001158.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Sad/0020_001399.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Sad/0020_001372.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Sad/0020_001400.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Sad/0020_001366.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Sad/0020_001206.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Sad/0020_001212.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Sad/0020_001213.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Sad/0020_001207.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Sad/0020_001367.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Sad/0020_001373.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Sad/0020_001398.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Sad/0020_001159.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Sad/0020_001165.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Sad/0020_001171.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Sad/0020_001116.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Sad/0020_001102.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Sad/0020_001328.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Sad/0020_001314.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Sad/0020_001300.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Sad/0020_001248.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Sad/0020_001260.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Sad/0020_001274.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Sad/0020_001089.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Sad/0020_001062.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Sad/0020_001076.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Sad/0020_001077.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Sad/0020_001063.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Sad/0020_001088.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Sad/0020_001275.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Sad/0020_001261.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Sad/0020_001249.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Sad/0020_001301.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Sad/0020_001315.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Sad/0020_001329.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Sad/0020_001103.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Sad/0020_001117.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Sad/0020_001129.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Sad/0020_001101.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Sad/0020_001115.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Sad/0020_001303.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Sad/0020_001317.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Sad/0020_001288.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Sad/0020_001277.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Sad/0020_001263.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Sad/0020_001075.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Sad/0020_001061.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Sad/0020_001060.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Sad/0020_001074.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Sad/0020_001262.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Sad/0020_001276.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Sad/0020_001289.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Sad/0020_001316.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Sad/0020_001302.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Sad/0020_001114.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Sad/0020_001100.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Sad/0020_001128.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Sad/0020_001104.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Sad/0020_001110.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Sad/0020_001138.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Sad/0020_001306.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Sad/0020_001312.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Sad/0020_001299.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Sad/0020_001272.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Sad/0020_001266.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Sad/0020_001070.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Sad/0020_001064.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Sad/0020_001058.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Sad/0020_001059.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Sad/0020_001065.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Sad/0020_001071.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Sad/0020_001267.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Sad/0020_001273.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Sad/0020_001298.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Sad/0020_001313.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Sad/0020_001307.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Sad/0020_001139.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Sad/0020_001111.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Sad/0020_001105.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Sad/0020_001113.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Sad/0020_001107.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Sad/0020_001311.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Sad/0020_001305.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Sad/0020_001339.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Sad/0020_001265.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Sad/0020_001271.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Sad/0020_001259.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Sad/0020_001098.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Sad/0020_001067.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Sad/0020_001073.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Sad/0020_001072.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Sad/0020_001066.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Sad/0020_001099.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Sad/0020_001258.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Sad/0020_001270.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Sad/0020_001264.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Sad/0020_001338.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Sad/0020_001304.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Sad/0020_001310.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Sad/0020_001106.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Sad/0020_001112.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Sad/0020_001137.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Sad/0020_001123.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Sad/0020_001309.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Sad/0020_001335.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Sad/0020_001321.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Sad/0020_001282.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Sad/0020_001296.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Sad/0020_001269.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Sad/0020_001241.wav
# ...
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Surprise/0020_001551.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Surprise/0020_001545.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Surprise/0020_001579.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Surprise/0020_001592.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Surprise/0020_001586.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Surprise/0020_001425.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Surprise/0020_001431.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Surprise/0020_001419.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Surprise/0020_001627.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Surprise/0020_001633.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Surprise/0020_001619.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Surprise/0020_001625.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Surprise/0020_001631.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Surprise/0020_001427.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Surprise/0020_001433.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Surprise/0020_001590.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Surprise/0020_001584.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Surprise/0020_001553.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Surprise/0020_001547.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Surprise/0020_001745.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Surprise/0020_001744.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Surprise/0020_001750.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Surprise/0020_001546.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Surprise/0020_001552.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Surprise/0020_001585.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Surprise/0020_001591.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Surprise/0020_001432.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Surprise/0020_001426.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Surprise/0020_001630.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Surprise/0020_001624.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Surprise/0020_001618.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Surprise/0020_001620.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Surprise/0020_001634.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Surprise/0020_001608.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Surprise/0020_001422.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Surprise/0020_001436.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Surprise/0020_001595.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Surprise/0020_001581.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Surprise/0020_001556.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Surprise/0020_001542.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Surprise/0020_001740.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Surprise/0020_001741.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Surprise/0020_001543.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Surprise/0020_001557.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Surprise/0020_001580.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Surprise/0020_001594.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Surprise/0020_001437.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Surprise/0020_001423.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Surprise/0020_001609.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Surprise/0020_001635.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Surprise/0020_001621.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Surprise/0020_001637.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Surprise/0020_001623.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Surprise/0020_001435.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Surprise/0020_001421.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Surprise/0020_001409.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Surprise/0020_001582.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Surprise/0020_001596.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Surprise/0020_001541.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Surprise/0020_001555.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Surprise/0020_001569.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Surprise/0020_001743.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Surprise/0020_001742.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Surprise/0020_001568.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Surprise/0020_001554.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Surprise/0020_001540.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Surprise/0020_001597.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Surprise/0020_001583.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Surprise/0020_001408.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Surprise/0020_001420.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Surprise/0020_001434.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Surprise/0020_001622.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Surprise/0020_001636.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Neutral/0020_000294.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Neutral/0020_000280.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Neutral/0020_000257.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Neutral/0020_000243.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Neutral/0020_000096.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Neutral/0020_000082.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Neutral/0020_000055.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Neutral/0020_000041.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Neutral/0020_000069.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Neutral/0020_000121.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Neutral/0020_000135.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Neutral/0020_000109.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Neutral/0020_000323.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Neutral/0020_000337.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Neutral/0020_000336.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Neutral/0020_000322.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Neutral/0020_000108.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Neutral/0020_000134.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Neutral/0020_000120.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Neutral/0020_000068.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Neutral/0020_000040.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Neutral/0020_000054.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Neutral/0020_000083.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Neutral/0020_000097.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Neutral/0020_000242.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Neutral/0020_000256.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Neutral/0020_000281.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Neutral/0020_000295.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Neutral/0020_000283.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Neutral/0020_000297.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Neutral/0020_000240.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Neutral/0020_000254.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Neutral/0020_000268.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Neutral/0020_000081.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Neutral/0020_000095.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Neutral/0020_000042.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Neutral/0020_000056.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Neutral/0020_000136.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Neutral/0020_000122.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Neutral/0020_000334.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Neutral/0020_000320.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Neutral/0020_000308.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Neutral/0020_000309.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Neutral/0020_000321.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Neutral/0020_000335.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Neutral/0020_000123.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Neutral/0020_000137.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Neutral/0020_000057.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Neutral/0020_000043.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Neutral/0020_000094.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Neutral/0020_000080.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Neutral/0020_000269.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Neutral/0020_000255.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Neutral/0020_000241.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Neutral/0020_000296.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Neutral/0020_000282.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Neutral/0020_000286.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Neutral/0020_000292.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Neutral/0020_000279.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Neutral/0020_000245.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Neutral/0020_000251.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Neutral/0020_000084.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Neutral/0020_000090.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Neutral/0020_000047.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Neutral/0020_000053.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Neutral/0020_000133.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Neutral/0020_000127.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Neutral/0020_000319.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Neutral/0020_000331.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Neutral/0020_000325.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Neutral/0020_000324.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Neutral/0020_000330.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Neutral/0020_000318.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Neutral/0020_000126.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Neutral/0020_000132.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Neutral/0020_000052.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Neutral/0020_000046.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Neutral/0020_000091.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Neutral/0020_000085.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Neutral/0020_000250.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Neutral/0020_000244.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Neutral/0020_000278.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Neutral/0020_000293.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Neutral/0020_000287.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Neutral/0020_000291.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Neutral/0020_000285.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Neutral/0020_000252.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Neutral/0020_000246.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Neutral/0020_000093.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Neutral/0020_000087.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Neutral/0020_000078.wav
# Sample rate is already 16000 Hz for file: ./Emotion_Speech_Dataset/0020/Neutral/0020_000050.wav

# %%
data_dict['Emotion_Speech_Dataset']
# Out:
#                                                File_Path Emotion Gender  \
# 0      ./Emotion_Speech_Dataset/0020/Happy/0020_00092...     hap   male
# 1      ./Emotion_Speech_Dataset/0020/Happy/0020_00091...     hap   male
# 2      ./Emotion_Speech_Dataset/0020/Happy/0020_00090...     hap   male
# 3      ./Emotion_Speech_Dataset/0020/Happy/0020_00073...     hap   male
# 4      ./Emotion_Speech_Dataset/0020/Happy/0020_00072...     hap   male
# ...                                                  ...     ...    ...
# 17495  ./Emotion_Speech_Dataset/0014/Angry/0014_00049...     ang   male
# 17496  ./Emotion_Speech_Dataset/0014/Angry/0014_00044...     ang   male
# 17497  ./Emotion_Speech_Dataset/0014/Angry/0014_00045...     ang   male
# 17498  ./Emotion_Speech_Dataset/0014/Angry/0014_00053...     ang   male
# 17499  ./Emotion_Speech_Dataset/0014/Angry/0014_00052...     ang   male
#
#        Duration
# 0         3.850
# 1         3.088
# 2         3.834
# 3         3.534
# 4         3.312
# ...         ...
# 17495     2.420
# 17496     2.239
# 17497     3.786
# 17498     3.137
# 17499     5.076
#
# [17500 rows x 4 columns]

# %%
# from pydub import AudioSegment
# import pandas as pd

# # Assuming df is your DataFrame with a column named "File_Path"
# # For example:
# # df = pd.read_csv('your_dataframe.csv')

# def get_wav_sample_rate(file_path):
#     audio = AudioSegment.from_file(file_path)
#     sample_rate = audio.frame_rate
#     return sample_rate

# # Apply the function to each row in the "File_Path" column
# data_dict[dataset[0]]['Sample_Rate'] =  data_dict[dataset[0]]['File_Path'].apply(get_wav_sample_rate)

# # Print the result
# #print(df[['File_Path', 'Sample_Rate']])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 14
#      11     return sample_rate
#      13 # Apply the function to each row in the "File_Path" column
# ---> 14 data_dict[dataset[0]]['Sample_Rate'] =  data_dict[dataset[0]]['File_Path'].apply(get_wav_sample_rate)
#      16 # Print the result
#      17 #print(df[['File_Path', 'Sample_Rate']])
#
# NameError: name 'dataset' is not defined

# %%
print(data_dict[dataset[0]][['File_Path', 'Sample_Rate']])
# Out:
#                                                File_Path  Sample_Rate
# 0      ./Emotion_Speech_Dataset/0020/Happy/0020_00092...        16000
# 1      ./Emotion_Speech_Dataset/0020/Happy/0020_00091...        16000
# 2      ./Emotion_Speech_Dataset/0020/Happy/0020_00090...        16000
# 3      ./Emotion_Speech_Dataset/0020/Happy/0020_00073...        16000
# 4      ./Emotion_Speech_Dataset/0020/Happy/0020_00072...        16000
# ...                                                  ...          ...
# 17495  ./Emotion_Speech_Dataset/0014/Angry/0014_00049...        16000
# 17496  ./Emotion_Speech_Dataset/0014/Angry/0014_00044...        16000
# 17497  ./Emotion_Speech_Dataset/0014/Angry/0014_00045...        16000
# 17498  ./Emotion_Speech_Dataset/0014/Angry/0014_00053...        16000
# 17499  ./Emotion_Speech_Dataset/0014/Angry/0014_00052...        16000
#
# [17500 rows x 2 columns]

# %%
# Combine all DataFrames from the dictionary into one large DataFrame
combined_df = pd.concat(data_dict.values(), ignore_index=True)

# %%
combined_df['Emotion'].value_counts()
# Out:
# neu            14747
# ang             9233
# hap             8157
# sad             7341
# sur             5487
# dis             2896
# xxx             2507
# fea             1913
# fru             1849
# sleepy          1721
# amused          1317
# exc             1281
# apologetic       240
# assertive        240
# anxious          240
# concerned        240
# encouraging      240
# calm             184
# oth                3
# Name: Emotion, dtype: int64

# %%
combined_df
# Out:
#                                                File_Path      Emotion  Gender  \
# 0      ./Emotion_Speech_Dataset/0020/Happy/0020_00092...          hap    male
# 1      ./Emotion_Speech_Dataset/0020/Happy/0020_00091...          hap    male
# 2      ./Emotion_Speech_Dataset/0020/Happy/0020_00090...          hap    male
# 3      ./Emotion_Speech_Dataset/0020/Happy/0020_00073...          hap    male
# 4      ./Emotion_Speech_Dataset/0020/Happy/0020_00072...          hap    male
# ...                                                  ...          ...     ...
# 59831  ./JL_corpus/Raw_JL_corpus/wav_txt/male1_anxiou...      anxious    male
# 59832  ./JL_corpus/Raw_JL_corpus/wav_txt/female2_anxi...      anxious  female
# 59833  ./JL_corpus/Raw_JL_corpus/wav_txt/male1_excite...          exc    male
# 59834  ./JL_corpus/Raw_JL_corpus/wav_txt/female1_enco...  encouraging  female
# 59835  ./JL_corpus/Raw_JL_corpus/wav_txt/male2_neutra...          neu    male
#
#        Duration
# 0         3.850
# 1         3.088
# 2         3.834
# 3         3.534
# 4         3.312
# ...         ...
# 59831     1.850
# 59832     2.300
# 59833     2.400
# 59834     2.000
# 59835     2.000
#
# [59836 rows x 4 columns]

# %%
import matplotlib.pyplot as plt

# Assuming you have already imported your data into combined_df
# If not, make sure to load your data first

# Group the data by 'Gender' and count the occurrences
gender_counts = combined_df['Gender'].value_counts()

# Create a bar plot
plt.figure(figsize=(8, 6))
ax = gender_counts.plot(kind='bar', color=['pink', 'blue'])
plt.title('Gender Distribution in Combined Dataset (train)')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.xticks(rotation=0)  # Optional: rotate x-axis labels

# Add numbers to the legend
for i, count in enumerate(gender_counts):
    plt.text(i, count, str(count), ha='center', va='bottom')

plt.show()

# %%
import matplotlib.pyplot as plt

# Count the frequency of each unique emotion value in the "Emotion" column
emotion_counts = combined_df['Emotion'].value_counts()

# Create a bar plot
plt.figure(figsize=(10, 6))
emotion_counts.plot(kind='bar')
plt.title('Distribution of Emotion Values (train)')
plt.xlabel('Emotion')
plt.ylabel('Count')
plt.xticks(rotation=45)

# Add a vertical red line at "fru" on the x-axis
plt.axvline(x=emotion_counts.index.get_loc('fea'), color='red', linestyle='--', label='combined emotions')

# Show the legend
plt.legend()

plt.show()

# %%
import pandas as pd

# List of emotions to keep
emotions_to_plot = ['neu', 'hap', 'ang', 'sad', 'sur', 'dis', 'fea']
# Filter the DataFrame to keep only specified emotions
filtered_df = combined_df[combined_df['Emotion'].isin(emotions_to_plot)]
# Display the result
print(filtered_df)
# Out:
#                                                File_Path Emotion  Gender  \
# 0      ./Emotion_Speech_Dataset/0020/Happy/0020_00092...     hap    male
# 1      ./Emotion_Speech_Dataset/0020/Happy/0020_00091...     hap    male
# 2      ./Emotion_Speech_Dataset/0020/Happy/0020_00090...     hap    male
# 3      ./Emotion_Speech_Dataset/0020/Happy/0020_00073...     hap    male
# 4      ./Emotion_Speech_Dataset/0020/Happy/0020_00072...     hap    male
# ...                                                  ...     ...     ...
# 59820  ./JL_corpus/Raw_JL_corpus/wav_txt/female2_neut...     neu  female
# 59823  ./JL_corpus/Raw_JL_corpus/wav_txt/female1_happ...     hap  female
# 59825  ./JL_corpus/Raw_JL_corpus/wav_txt/male1_sad_15...     sad    male
# 59829  ./JL_corpus/Raw_JL_corpus/wav_txt/male1_sad_13...     sad    male
# 59835  ./JL_corpus/Raw_JL_corpus/wav_txt/male2_neutra...     neu    male
#
#        Duration
# 0         3.850
# 1         3.088
# 2         3.834
# 3         3.534
# 4         3.312
# ...         ...
# 59820     2.300
# 59823     2.200
# 59825     2.400
# 59829     1.750
# 59835     2.000
#
# [49774 rows x 4 columns]

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# Create a figure and axis
fig, ax = plt.subplots(figsize=(10, 6))

# Plot a histogram with a density curve
sns.histplot(filtered_df['Duration'], kde=True, ax=ax, bins=1000)

# Highlight durations above 15 and below 1
plt.axvline(12, color='red', linestyle='--', linewidth=2, label='Duration > 12 Threshold')
plt.axvline(3, color='green', linestyle='--', linewidth=2, label='Duration < 3 Threshold')

# Add labels and legend
plt.xlabel('Duration')
plt.ylabel('Density')
plt.title('Distribution of Duration with Thresholds')

# Show the plot
plt.legend()
plt.show()

# %%
min = 3
max = 12
filtered_df = filtered_df[(filtered_df['Duration'] > min) & (filtered_df['Duration'] < max)]

# Display the resulting DataFrame
print()
# Sum the Duration column in seconds
total_duration_seconds = filtered_df['Duration'].sum()

# Convert total duration to hours
total_duration_hours = total_duration_seconds / 3600  # 1 hour = 3600 seconds

# Display the total duration in hours
print(f'Total Duration (hours): {total_duration_hours} , threshold: {min , max}')
# Out:
# Total Duration (hours): 24.175930833333336 , threshold: (3, 12)

# %%
print(filtered_df['Emotion'].value_counts())
# Out:
# neu    5559
# ang    4072
# sad    3144
# hap    2548
# dis    1817
# sur    1774
# fea     581
# Name: Emotion, dtype: int64

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming filtered_df is your DataFrame
# For example, if your DataFrame looks like this:
# filtered_df = pd.DataFrame({'File_Path': ['./savee/data/JK_sa01.wav', './savee/data/AB_sa02.wav', './savee/data/CD_sa03.wav']})

# Extract the first part of the paths and save them in a new column
filtered_df['dataset_name'] = filtered_df['File_Path'].str.split('/').str[1]

# Plot the dataset_name values
plt.figure(figsize=(10, 6))
filtered_df['dataset_name'].value_counts().plot(kind='bar', color='skyblue')
plt.title('Distribution of dataset_name')
plt.xlabel('dataset_name')
plt.ylabel('Count')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# Create a figure and axis
fig, ax = plt.subplots(figsize=(10, 6))

# Plot a histogram with a density curve
sns.histplot(filtered_df['Duration'], kde=True, ax=ax, bins=1000)


# Add labels and legend
plt.xlabel('Duration')
plt.ylabel('Density')
plt.title('Distribution of Duration with Thresholds')

# Show the plot
plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
import matplotlib.pyplot as plt

# Group the data by "Emotion" and calculate the total duration in hours for each group
emotion_duration_hours = filtered_df.groupby('Emotion')['Duration'].sum() / 3600

# Convert the result to a DataFrame for better visualization
emotion_duration_hours_df = emotion_duration_hours.reset_index()

# Rename the columns for clarity
emotion_duration_hours_df.columns = ['Emotion', 'Total Duration (Hours)']

# Sort the DataFrame in descending order by total duration
emotion_duration_hours_df = emotion_duration_hours_df.sort_values(by='Total Duration (Hours)', ascending=False)

# Create a descending bar plot
plt.figure(figsize=(10, 6))
plt.bar(emotion_duration_hours_df['Emotion'], emotion_duration_hours_df['Total Duration (Hours)'])
plt.title('Total Duration in Hours by Emotion (Descending) [train]')
plt.xlabel('Emotion')
plt.ylabel('Total Duration (Hours)')
plt.xticks(rotation=45)
plt.grid(True)

plt.show()

# %%
filtered_df
# Out:
#                                                File_Path Emotion  Gender  \
# 0      ./Emotion_Speech_Dataset/0020/Happy/0020_00092...     hap    male
# 1      ./Emotion_Speech_Dataset/0020/Happy/0020_00091...     hap    male
# 2      ./Emotion_Speech_Dataset/0020/Happy/0020_00090...     hap    male
# 3      ./Emotion_Speech_Dataset/0020/Happy/0020_00073...     hap    male
# 4      ./Emotion_Speech_Dataset/0020/Happy/0020_00072...     hap    male
# ...                                                  ...     ...     ...
# 57430  ./IEMOCAP_full_release/Sessions/Session5/sente...     sad  female
# 57435  ./IEMOCAP_full_release/Sessions/Session5/sente...     neu  female
# 57971  ./JL_corpus/Raw_JL_corpus/wav_txt/female2_sad_...     sad  female
# 58857  ./JL_corpus/Raw_JL_corpus/wav_txt/female2_sad_...     sad  female
# 59234  ./JL_corpus/Raw_JL_corpus/wav_txt/female1_sad_...     sad  female
#
#        Duration            dataset_name
# 0         3.850  Emotion_Speech_Dataset
# 1         3.088  Emotion_Speech_Dataset
# 2         3.834  Emotion_Speech_Dataset
# 3         3.534  Emotion_Speech_Dataset
# 4         3.312  Emotion_Speech_Dataset
# ...         ...                     ...
# 57430     5.720    IEMOCAP_full_release
# 57435    11.370    IEMOCAP_full_release
# 57971     3.750               JL_corpus
# 58857     3.400               JL_corpus
# 59234     3.050               JL_corpus
#
# [19495 rows x 5 columns]

# %%
# Save the filtered DataFrame to a CSV file
filtered_df.to_csv('/home/adham.ibrahim/speech_datasets/train/train_df.csv', index=False)

# %%
import pandas as pd

# Specify the file path
file_path = '/home/adham.ibrahim/speech_datasets/train/train_df.csv'

# Read the CSV file into a DataFrame
df = pd.read_csv(file_path)

# Display the DataFrame
print(df.head())
# Out:
#                                            File_Path Emotion Gender  Duration  \
# 0  ./Emotion_Speech_Dataset/0020/Happy/0020_00092...     hap   male     3.850
# 1  ./Emotion_Speech_Dataset/0020/Happy/0020_00091...     hap   male     3.088
# 2  ./Emotion_Speech_Dataset/0020/Happy/0020_00090...     hap   male     3.834
# 3  ./Emotion_Speech_Dataset/0020/Happy/0020_00073...     hap   male     3.534
# 4  ./Emotion_Speech_Dataset/0020/Happy/0020_00072...     hap   male     3.312
#
#              dataset_name
# 0  Emotion_Speech_Dataset
# 1  Emotion_Speech_Dataset
# 2  Emotion_Speech_Dataset
# 3  Emotion_Speech_Dataset
# 4  Emotion_Speech_Dataset

# %%
# Assuming df is your DataFrame
emov_db_rows = df[df['dataset_name'] == 'emov_db']

# Display the filtered DataFrame
print(emov_db_rows)
# Out:
#                                               File_Path Emotion Gender  \
# 5438        ./emov_db/sam/sam_Angry/anger_1-28_0011.wav     ang   male
# 5439      ./emov_db/sam/sam_Angry/anger_85-112_0111.wav     ang   male
# 5440      ./emov_db/sam/sam_Angry/anger_85-112_0105.wav     ang   male
# 5441       ./emov_db/sam/sam_Angry/anger_29-56_0047.wav     ang   male
# 5442       ./emov_db/sam/sam_Angry/anger_29-56_0053.wav     ang   male
# ...                                                 ...     ...    ...
# 8862  ./emov_db/josh/josh_Neutral/neutral_169-196_01...     neu   male
# 8863  ./emov_db/josh/josh_Neutral/neutral_169-196_01...     neu   male
# 8864  ./emov_db/josh/josh_Neutral/neutral_141-168_01...     neu   male
# 8865  ./emov_db/josh/josh_Neutral/neutral_141-168_01...     neu   male
# 8866  ./emov_db/josh/josh_Neutral/neutral_29-56_0032...     neu   male
#
#       Duration dataset_name
# 5438     4.310      emov_db
# 5439     4.881      emov_db
# 5440     4.829      emov_db
# 5441     5.124      emov_db
# 5442     3.812      emov_db
# ...        ...          ...
# 8862     3.025      emov_db
# 8863     3.803      emov_db
# 8864     3.966      emov_db
# 8865     3.403      emov_db
# 8866     3.516      emov_db
#
# [3429 rows x 5 columns]
